# %%
import pandas as pd

# %%
# Read in the data
df = pd.read_csv('Nirvana_All_perfs.csv')
df.head()
# Out:
#                  original_venue original_city original_state original_country  \
# 0                   house party      Aberdeen             WA    United States
# 1              17 Nussbaum Road       Raymond             WA    United States
# 2       Community World Theater        Tacoma             WA    United States
# 3                        GESCCO       Olympia             WA    United States
# 4  KAOS Olympia Community Radio       Olympia             WA    United States
#
#    original_month  original_day  original_year        lat         lon  \
# 0             NaN           NaN           1987  46.975371 -123.815722
# 1             3.0           NaN           1987  46.686484 -123.732946
# 2             4.0          18.0           1987  47.245501 -122.438329
# 3             5.0           1.0           1987  47.045102 -122.895008
# 4             5.0           6.0           1987  47.045102 -122.895008
#
#                                      formatted  ...               county  \
# ...
